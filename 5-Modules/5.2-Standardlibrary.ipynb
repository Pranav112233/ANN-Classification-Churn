# %%
print('Hello')
# Out:
# Hello

# %%
''' 
Standard Library Overview:-

Python's Standard Library is a vast collection of modules and packages that come bundled with Python,
providing a wide range of functionalities out of the box
Here's an overview of some of the most commonly used modules and packages in the Python Standard Library.
'''
# Out:
# " \nStandard Library Overview:-\n\nPython's Standard Library is a vast collection of modules and packages that come bundled with Python,\nproviding a wide range of functionalities out of the box. Here's an overview of some of the most commonly used modules and packages in the Python Standard Library.\n"

# %%
import array 
arr = array.array('i', [1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## random
import random
print(random.randint(1,10))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 7
# banana

# %%
## File and Directory Access

import os
print(os.getcwd())
# Out:
# c:\Users\Lenovo\Desktop\Python For DS\5-Modules

# %%
os.mkdir('test_dir')

# %%
## High Level Operations on Files and Collection of Files
import shutil
shutil.copyfile('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization

import json
data = {'name':'Krish', 'age':25}
#Json we get in form of API from an API
json_str = json.dumps(data)
print(json_str)
print(type(json_str))
#Convert it into dictionary format
parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Krish", "age": 25}
# <class 'str'>
# {'name': 'Krish', 'age': 25}
# <class 'dict'>

# %%
## csv
import  csv
with open('example.csv', mode='w',newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['Krish',32])

with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Krish', '32']

# %%
## datetime
from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)

print(yesterday)
# Out:
# 2026-03-15 01:30:59.671345
# 2026-03-14 01:30:59.671345

# %%
## time
# make the program sleep for certain seconds

import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1773518533.6291106
# 1773518535.6300633

# %%
## Regular expression
import re

pattern = r'\d+' #d -> digits
text = 'There are 123 apples'
match = re.search(pattern, text)
print(match.group())
# Out:
# 123
