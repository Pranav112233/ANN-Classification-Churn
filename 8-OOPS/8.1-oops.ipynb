# %%
print('Hello')
# Out:
# Hello

# %%
'''  
Classes and Objects
Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs.
OOP allows for modeling real-world scenarios using classes and objects.
This lesson covers the basics of creating classes and objects, including instance variables and methods.
'''
# Out:
# '  \nClasses and Objects\nObject-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs.\nOOP allows for modeling real-world scenarios using classes and objects.\nThis lesson covers the basics of creating classes and objects, including instance variables and methods.\n'

# %%
### A class is a blue print for creating objects. Attributes, methods

class Car: #Class
    pass

audi=Car() #obj1
bmw=Car() #obj2

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)
# Out:
# <__main__.Car object at 0x000001421E84D7F0>
# <__main__.Car object at 0x000001421E68D950>

# %%
audi.windows = 4 #windows -> attribute of object(audi)
print(audi.windows)
# Out:
# 4

# %%
tata=Car()
tata.doors=4
print(tata.doors)
# Out:
# 4

# %%
### Instance Variable and Methods
class Dog:
    #Constructor
    def __init__(self,name,age):
        name = name
        self.name = name
        self.age = age

## Create an object
dog1 = Dog("Buddy",3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# <__main__.Dog object at 0x000001421E84DA90>
# Buddy
# 3

# %%
dog2 = Dog("Lucy",4)
print(dog2.name)
print(dog2.age)
# Out:
# Lucy
# 4

# %%
## Instance Methods

# Define a class with Instance Methods
class Dog:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def bark(self):
        print(f"{self.name} says woof")


dog2 = Dog("Buddy",3)
print(dog2.name)
print(dog2.age)
dog2.bark()
# Out:
# Buddy
# 3
# Buddy says woof

# %%
# Modeling a Bank Account

# Define a class for bank account
class BankAccount: #constructor
    def __init__(self, owner, balance=0):
        self.owner = owner #instance variable
        self.balance = balance
#instance methods
    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} is deposited. New balance is {self.balance}")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient Funds!")
        else:
            self.balance -= amount
            print(f"{amount} is withdrawn. New Balance is {self.balance}")

    def get_balance(self):
        return self.balance
    
## Create an object
account = BankAccount("Krish", 5000)
print(account.balance)
# Out:
# 5000

# %%
# Call instance methods
account.deposit(100)
# Out:
# 100 is deposited. New balance is 5100

# %%
account.withdraw(300)
# Out:
# 300 is withdrawn. New Balance is 4800

# %%
print(account.get_balance())
# Out:
# 4800
