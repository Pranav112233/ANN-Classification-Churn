# %%
print('Hello')
# Out:
# Hello

# %%
## Using the OS module
import os
cwd = os.getcwd()
print(f"Current Working Directory {cwd}")
# Out:
# Current Working Directory c:\Users\Lenovo\Desktop\Python For DS\6-File Handling

# %%
## Create a new directory
new_directory = "package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}'create ")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[3], line 3
#       1 ## Create a new directory
#       2 new_directory = "package"
# ----> 3 os.mkdir(new_directory)
#       4 print(f"Directory '{new_directory}'create ")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'package'

# %%
## List all the  Files and Directories

items = os.listdir('.')
print(items)
# Out:
# ['6.1-fileoperation.ipynb', '6.2-filepath.ipynb', 'destination.txt', 'example.bin', 'example.txt', 'package']

# %%
###  Joining Paths

dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(),dir_name, file_name)
print(full_path)
# Out:
# c:\Users\Lenovo\Desktop\Python For DS\6-File Handling\folder\file.txt

# %%
# To check file is present or not

path = 'example1.txt'
if os.path.exists(path):
    print(f"The Path '{path}'Exists")
else:
    print(f"The path '{path} does not exist")
# Out:
# The path 'example1.txt does not exist

# %%
# Checking if a PAth is a File or Directory

import os
path = 'example.txt' 
if os.path.isfile(path):
    print(f"The Path '{path}' i a file.")
elif os.path.isdir(path):
    print(f"THe path '{path}' is a directory.")
else:
    print(f"The path '{path}' is neither a file nor a directory.")
# Out:
# The Path 'example.txt' i a file.

# %%
# Getting the absolute path
relative_path = 'example.txt'

absolute_path = os.path.abspath(relative_path)

print(absolute_path)
# Out:
# c:\Users\Lenovo\Desktop\Python For DS\6-File Handling\example.txt
