# %%
a = 100

# %%
## Declaring and assiigning variables

age = 32
height = 6.1
name = "Krish"

is_student = True

#Printing variables
print("age:", age)
print("height:",height)
print("Name:", name)
print(is_student)
# Out:
# age: 32
# height: 6.1
# Name: Krish
# True

# %%
## Naming Conventions
## Variable names should be descriptive
## They must always start with a letter or an '_' and contain letter, numbers and underscores
## Variables names are case sensitive

# Valid variables

first_name = "Krish"
last_name = "Naik"

# %%
## Invalid Variable Names
#2age = 30
#first-name = "Krish"
# @name = "Krish"

# %%
## Case Sensitivity
name = "Krish"
Name = "Naik"

# %%
## Understanding Variable types
## Python is dynamically types, type of a variable is determined at runtime

age = 25 #int
height = 6.1 #float
name = "Krish" #str
is_student = True #Bool

print(type(name))
# Out:
# <class 'str'>

# %%
## Type Checking and Conversion

type(height)
# Out:
# float

# %%
age = 25
print(type(age))
# Out:
# <class 'int'>

# %%
# Type Conversion
age_str = str(age)

print(age_str)
print(type(age_str))
# Out:
# 25
# <class 'str'>

# %%
age = '25'
int(age)

print(type(int(age)))
# Out:
# <class 'int'>

# %%
# can't type cast this
# name="krish"
#int(name)

# %%
height = 5.11
type(height)
# Out:
# float

# %%
int(height) #type cast
float(int(height)) #type cast again
# Out:
# 5.0

# %%
## Dynamic Typing
## Python allows the type of a variable to change as the program executes


var = 10 #int
print(var, type(var))


var = "Hello"
print(var, type(var))

var = 3.14
print(var, type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
# input

age = int(input("What is the age"))
print(age)
print(type(age))
# Out:
# 23
# <class 'int'>

# %%
## Simple Calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

sum = num1 + num2
diff = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum:", sum)
print("Difference:",diff)
print("Product:",product)
print("Quotient:",quotient)
# Out:
# Sum: 3.0
# Difference: -1.0
# Product: 2.0
# Quotient: 0.5
