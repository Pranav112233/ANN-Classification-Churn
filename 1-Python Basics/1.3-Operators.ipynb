# %%
#1. Intro to Operators
#2. Arithmetic Operators
#3. Comparison Operators
#4. Logical Operators
#5. Practical Examples and Errors

# %%
##Arithmetic Operatation

a = 10
b =5

add_result = a + b #add
sub_result = a - b #sub
mult_result = a * b #mult
div_result = a / b #div
floor_div_result = a // b #floor division
modulus_result = a % b ##modulus
exponent_result = a ** b #Exponentiation


print(add_result)
print(sub_result)
print(mult_result)
print(div_result)
print(floor_div_result)
print(modulus_result)
print(exponent_result)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
10 / 5
# Out:
# 2.0

# %%
21 // 5
# Out:
# 4

# %%
## Comparison Operators

## ==  Equal to Operator

a = 10
b = 10

a == b
# Out:
# True

# %%
str1 = "Krish"
str2 = "krish"

str1 == str2
# Out:
# False

# %%
## !=   Not Eual to
str1 != str2
# Out:
# True

# %%
str3 = "Krish"
str4 = "krish"

str3 != str4
# Out:
# True

# %%
## Greater than

num1 = 45
num2 = 55
num1 > num2
# Out:
# False

# %%
## Less than

num1 < num2
# Out:
# True

# %%
## Greater than or eual to
number1 = 44
number2 = 45

number1 >= number2
# Out:
# False

# %%
## Less than or equal to
number1 <= number2
# Out:
# True

# %%
#### Logical Operators

## And, Not, OR

X = True
Y = True

result = X and Y
print(result)
# Out:
# True

# %%
X = True
Y = False

result = X and Y
print(result)
# Out:
# False

# %%
## OR operation
# Both false => o/p = False
X = False
Y = False

result = X and Y
print(result)
# Out:
# False

# %%
#Either on is true => o/p = True
X = True
Y = True

result = X and Y
print(result)
# Out:
# True

# %%
## NOT operator

x = True
not X
# Out:
# False

# %%
## Simple calculator

# Simple calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
# Performing arithmetic operations
addition = num1 + num2
subtraction = num1 - num2
multiplication = num1* num2
division = num1 / num2
floor_division = num1 // num2
modulus = num1% num2
exponentiation = num1 ** num2
#Displaying results
print("Addition:", addition)
print("Subtraction:", subtraction)
print("Multiplication:", multiplication)
print("Division:", division)
print("Floor Division:", floor_division)
print("Modulus:", modulus)
print("Exponentiation:", exponentiation)
# Out:
# Addition: 3.0
# Subtraction: -1.0
# Multiplication: 2.0
# Division: 0.5
# Floor Division: 0.0
# Modulus: 1.0
# Exponentiation: 1.0

# %%
## If-else Statement

age = 20

if age >= 18:
    print("You are allowed to vote in the elections.")
else:
    print("Not eligible to vote")
# Out:
# You are allowed to vote in the elections.

# %%
## elif statement
# allow to check multiple contidions is it " else if "
age = 20

if age < 13:
    print("You are a child")
elif age < 18:
    print("You are a teenage")
else:
    print("You are an Adult")
# Out:
# You are an Adult

# %%
#Nested Conditional Statments

# inside one "if elif or else" statements put multiple "if elif or else " statements.

num = int(input("Enter a number"))

if num >= 0:
    print("Number is positive")
    if num % 2 == 0:
        print("Number is even")
    else:
        print("Number is odd")
else:
    print("Number is negative")
# Out:
# Number is positive
# Number is even

# %%
## Practical Examples

## Determine if a year is a leap year using nested condition statement

year = int(input("Enter a year"))

if year % 4 ==0:
    if year % 200 == 0:
        if year % 400 == 0:
            print(year, " is a leap year")
        else:
            print(year, " not a leap year")
    else:
        print(year, " is a leap year")
else:
    print(year, " is not a leap year")
# Out:
# 2002  is not a leap year

# %%
## Assignments = > Simple calculator program

num1 = float(input("Enter first num"))
num2 = float(input("Enter second num"))

operation = input("Enter operation ( +, -, *, /):")

#Perform the requested operation
if operation == '+':
    result = num1 + num2
elif operation == '-':
    result = num1 - num2
elif operation == '*':
    result = num1 * num2
elif operation == '/':
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error"

else:
    result = "Invalid Operation"

print("Result:", result)
# Out:
# Result: 3.0
