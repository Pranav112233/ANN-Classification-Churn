# %%
## Integer Example
age = 35
print(age)
# Out:
# 35

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
## Floating point datatype
height = 5.11
print(height)
print(type(height))
# Out:
# 5.11
# <class 'float'>

# %%
## String datatype example

name ="Krish"
print(name)
print(type(name))
# Out:
# Krish
# <class 'str'>

# %%
## Boolean datatype

is_true = True
type(is_true)
# Out:
# bool

# %%
is_true = bool()

# %%
a = 10
b = 10

type(a == b)
# Out:
# bool

# %%
## Common Errors

result = "Hello " + str(50)
print(result)
# Out:
# Hello 50
