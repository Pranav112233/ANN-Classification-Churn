# %% [markdown]
# ### 5 number Summary and Box Plot

# %%
## Minimum, maximum, median, Q1, Q3, IQR

# %%
import numpy as np

# %%
lst_marks = [45,32,56,74,89,67,90,87,67,58,63,45,74]
minimum, Q1, median, Q3, maximum = np.quantile(lst_marks, [0, 0.25, 0.50, 0.75, 1.0])

# %%
minimum, Q1, median, Q3, maximum
# Out:
# (np.float64(32.0),
#  np.float64(56.0),
#  np.float64(67.0),
#  np.float64(74.0),
#  np.float64(90.0))

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 18.0

# %%
lower_bound = Q1 - 1.5*IQR
higher_bound = Q3 + 1.5*IQR

# %%
lower_bound
# Out:
# np.float64(29.0)

# %%
higher_bound
# Out:
# np.float64(101.0)

# %%
lst_marks = [45,32,56,74,89,67,90,87,67,58,63,45,74]

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
# Adding Outliers
lst_marks = [100, 200, 45,32,56,74,89,67,90,87,67,58,63,45,74, 1000, 1200, 1300]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
