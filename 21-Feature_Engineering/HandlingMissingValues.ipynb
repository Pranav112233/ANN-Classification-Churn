# %%
print('Hello')
# Out:
# Hello

# %% [markdown]
# ### Missing Values

# %% [markdown]
# Missing values occurs in dataset when some of the informations is not stored for a variable There are 3 mechanisms

# %% [markdown]
# ### 1. Missing Completely at Random, MCAR:
# Missing completely at random (MCAR) is a type of missing data mechanism in which the probability of a value being missing is unrelated to both the observed data and the missing data. In other words, if the data is MCAR, the missing values are randomly distributed throughout the dataset, and there is no systematic reason for why they are missing.
#
#
# For example, in a survey about the prevalence of a certain disease, the missing data might be MCAR if the survey participants y values for certain questions were selected randomly and their missing responses are not related to their disease status or measured in the survey

# %% [markdown]
# ### 2. Missing at Random MAR:

# %% [markdown]
# Missing at Random (MAR) is a type of missing data mechanism in which the probability of a value being missing depends only on the observed data, but not on the missing data itself. In other words, if the data is MAR, the missing values are systematically related to the observed data, but not to the missing data. Here are a few examples of missing at random:
#
#
# Income data: Suppose you are collecting income data from a group of people, but some participants choose not to report their income. If the decision to report or not report income is related to the participant's age or gender, but not to their income level, then the data is missing at random.
#
#
# Medical data: Suppose you are collecting medical data on patients, including their blood pressure, but some patients do not pressure. If the patients who do not report their blood pressure are more likely to be younger or have healthier lifestyles, is not related to their actual blood pressure values, then the data is missing at random.

# %% [markdown]
# ### 3. Missing data not at random(MNAR)
#
# It is a type of missing data mechanism where the probability of missing values depends on the value of the missing data itself. In other words, if the data is MNAR, the missingness is not random and is dependent on unobserved or unmeasured factors that are associated with the missing values.
#
#
# For example, suppose you are collecting data on the income and job satisfaction of employees in a company. If employees who are less satisfied with their jobs are more likely to refuse to report their income, then the data is not missing at random. In this case, the missingness is dependent on job satisfaction, which is not directly observed or measured.

# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Check Missing Values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
## Removing Missing Values
df.shape
# Out:
# (891, 12)

# %%
df.dropna().shape #Removed all missing values
# Out:
# (183, 12)

# %%
## Remove Data Columnwise

df.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %% [markdown]
# ### Imputation Missing Values
#
#
# ### 1-> Mean Value Imputation

# %%
sns.histplot(df['Age'], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df['Age_mean']=df['Age'].fillna(df['Age'].mean())

# %%
df[['Age_mean','Age']]
# Out:
#       Age_mean   Age
# 0    22.000000  22.0
# 1    38.000000  38.0
# 2    26.000000  26.0
# 3    35.000000  35.0
# 4    35.000000  35.0
# ..         ...   ...
# 886  27.000000  27.0
# 887  19.000000  19.0
# 888  29.699118   NaN
# 889  26.000000  26.0
# 890  32.000000  32.0
#
# [891 rows x 2 columns]

# %%
## Mean Imputation works well when we habve normally distributed data

# %% [markdown]
# ### 2. Median Value Imputation -> If we have outliers in our dataset

# %%
df['Age_median'] = df['Age'].fillna(df['Age'].median())

# %%
df[['Age_median','Age_mean','Age']]
# Out:
#      Age_median   Age_mean   Age
# 0          22.0  22.000000  22.0
# 1          38.0  38.000000  38.0
# 2          26.0  26.000000  26.0
# 3          35.0  35.000000  35.0
# 4          35.0  35.000000  35.0
# ..          ...        ...   ...
# 886        27.0  27.000000  27.0
# 887        19.0  19.000000  19.0
# 888        28.0  29.699118   NaN
# 889        26.0  26.000000  26.0
# 890        32.0  32.000000  32.0
#
# [891 rows x 3 columns]

# %% [markdown]
# ### 3. Mode Value Imputation-> Can be used with Categorical Values

# %%
df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  Age_median  \
# 61   female  38.0      0      0  113572  80.0   B28      NaN        38.0
# 829  female  62.0      0      0  113572  80.0   B28      NaN        62.0
#
#      Age_mean
# 61       38.0
# 829      62.0

# %%
df['Embarked'].unique()
# Out:
# <StringArray>
# ['S', 'C', 'Q', nan]
# Length: 4, dtype: str

# %%
# Replace the nan with sum of other values
mode_val = df[df['Embarked'].notna()]['Embarked'].mode()[0]

# %%
mode_val
# Out:
# 'S'

# %%
df['Embarked_mode'] = df['Embarked'].fillna(mode_val)

# %%
df[['Embarked_mode','Embarked']]
# Out:
#     Embarked_mode Embarked
# 0               S        S
# 1               C        C
# 2               S        S
# 3               S        S
# 4               S        S
# ..            ...      ...
# 886             S        S
# 887             S        S
# 888             S        S
# 889             C        C
# 890             Q        Q
#
# [891 rows x 2 columns]

# %%
df['Embarked_mode'].isnull().sum()
# Out:
# np.int64(0)
