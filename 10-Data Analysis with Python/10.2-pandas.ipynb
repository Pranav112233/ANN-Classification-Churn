# %% [markdown]
# ### Pandas-DataFrame And Series
#
# Pandas is a powerful data manipulation library in Python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and DataFrame. A Series is a one-dimensional array-like object, while a DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns).

# %% [markdown]
# # Series -> 1D array object
# # DataFrame -> 2D array object

# %%
print('Hello')
# Out:
# Hello

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# ### Series

# %%
## Series

import pandas as pd
data = [1,2,3,4,5]
series = pd.Series(data)
print("Series \n", series)
print(type(series))
# Out:
# Series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.Series'>

# %%
## Create a Series From a Dictionary
data = {'a':1, 'b':2, 'c':3}
series_dict = pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = [10,20,30]
index=['a','b','c']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ### DataFrame

# %%
## DataFrame - 2D mutable,  hetrogenous tabular data structred with row and column

## create a dataframe from a dictionary of list

data = {
    'name':['Krish','John','Jack'],
    'age':[24,56,77],
    'city':['Patna','Bangalore','New York']
}

df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     name  age       city
# 0  Krish   24      Patna
# 1   John   56  Bangalore
# 2   Jack   77   New York
# <class 'pandas.DataFrame'>

# %%
## Create a DataFrame from a List of Dictionary

data1=[
{'Name': 'Krish', 'Age': 32, 'City': 'Bangalore'}, 
{'Name': 'John', 'Age': 34, 'City': 'Bangalore'}, 
{'Name': 'Bappy', 'Age':32, 'City': 'Bangalore'},
{'Name': 'JAck', 'Age':32, 'City': 'Bangalore'}
]
df=pd.DataFrame(data1)
print(df)
print(type(df))
# Out:
#     Name  Age       City
# 0  Krish   32  Bangalore
# 1   John   34  Bangalore
# 2  Bappy   32  Bangalore
# 3   JAck   32  Bangalore
# <class 'pandas.DataFrame'>

# %%
df = pd.read_csv('sales_data.csv')
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
df
# Out:
#     Name  Age       City
# 0  Krish   32  Bangalore
# 1   John   34  Bangalore
# 2  Bappy   32  Bangalore
# 3   JAck   32  Bangalore

# %%
## Accessing Data From DataFrame
data
# Out:
# {'name': ['Krish', 'John', 'Jack'],
#  'age': [24, 56, 77],
#  'city': ['Patna', 'Bangalore', 'New York']}

# %%
df
# Out:
#     Name  Age       City
# 0  Krish   32  Bangalore
# 1   John   34  Bangalore
# 2  Bappy   32  Bangalore
# 3   JAck   32  Bangalore

# %%
df['Name']
# Out:
# 0    Krish
# 1     John
# 2    Bappy
# 3     JAck
# Name: Name, dtype: str

# %%
type(df['Name'])
# Out:
# pandas.Series

# %%
# To go to the row index
df.loc[0]
# Out:
# Name        Krish
# Age            32
# City    Bangalore
# Name: 0, dtype: object

# %%
# To go to the col index
df.iloc[0]
# Out:
# Name        Krish
# Age            32
# City    Bangalore
# Name: 0, dtype: object

# %%
df
# Out:
#     Name  Age       City
# 0  Krish   32  Bangalore
# 1   John   34  Bangalore
# 2  Bappy   32  Bangalore
# 3   JAck   32  Bangalore

# %%
## Accessing a specified element
df.at[1,'Age']
# Out:
# np.int64(34)

# %%
## Accessing a specified element using iat
df.iat[2,2]
# Out:
# 'Bangalore'

# %% [markdown]
# ### Data Manipulation with DataFrames

# %%
# Adding a new column
import pandas as pd
df['Salary'] = pd.Series([50000,60000,70000])
df
# Out:
#     Name  Age       City   Salary
# 0  Krish   32  Bangalore  50000.0
# 1   John   34  Bangalore  60000.0
# 2  Bappy   32  Bangalore  70000.0
# 3   JAck   32  Bangalore      NaN

# %%
## Remove a column
df.drop('Salary',axis=1) #drop is not a permanent operation
# Out:
#     Name  Age       City
# 0  Krish   32  Bangalore
# 1   John   34  Bangalore
# 2  Bappy   32  Bangalore
# 3   JAck   32  Bangalore

# %%
df.drop('Salary', axis=1, inplace=True)

# %%
df
# Out:
#     Name  Age       City
# 0  Krish   32  Bangalore
# 1   John   34  Bangalore
# 2  Bappy   32  Bangalore
# 3   JAck   32  Bangalore

# %%
## Add age to the column
df['Age'] = df['Age'] + 1

# %%
df
# Out:
#     Name  Age       City
# 0  Krish   33  Bangalore
# 1   John   35  Bangalore
# 2  Bappy   33  Bangalore
# 3   JAck   33  Bangalore

# %%
# drop based on row
df
# Out:
#     Name  Age       City
# 0  Krish   33  Bangalore
# 1   John   35  Bangalore
# 2  Bappy   33  Bangalore
# 3   JAck   33  Bangalore

# %%
df.drop(0) #dropped first row completely
# Out:
#     Name  Age       City
# 1   John   35  Bangalore
# 2  Bappy   33  Bangalore
# 3   JAck   33  Bangalore

# %%
df.drop(0, inplace=True)

# %%
df
# Out:
#     Name  Age       City
# 1   John   35  Bangalore
# 2  Bappy   33  Bangalore
# 3   JAck   33  Bangalore

# %%
# Display the data types of each column 

print("Data types: \n", df.dtypes)

# Describe the DataFrame 

print("Statistical summary:\n", df.describe())
# Out:
# Data types:
#  Name      str
# Age     int64
# City      str
# dtype: object
# Statistical summary:
#               Age
# count   3.000000
# mean   33.666667
# std     1.154701
# min    33.000000
# 25%    33.000000
# 50%    33.000000
# 75%    34.000000
# max    35.000000

# %%
df.describe() #statistical summary
# Out:
#              Age
# count   3.000000
# mean   33.666667
# std     1.154701
# min    33.000000
# 25%    33.000000
# 50%    33.000000
# 75%    34.000000
# max    35.000000
